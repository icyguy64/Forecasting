# %%
"""
This is an upgraded version of Ceshine's and Linzhi and Andy Harless starter script, simply adding more
average features and weekly average features on it.
"""
from datetime import date, timedelta
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers import LSTM
from keras import callbacks
from keras.callbacks import ModelCheckpoint

df_train = pd.read_csv(
    '../input/train.csv', usecols=[1, 2, 3, 4, 5],
    dtype={'onpromotion': bool},
    converters={'unit_sales': lambda u: np.log1p(
        float(u)) if float(u) > 0 else 0},
    parse_dates=["date"],
    skiprows=range(1, 66458909)  # 2016-01-01
)

df_test = pd.read_csv(
    "../input/test.csv", usecols=[0, 1, 2, 3, 4],
    dtype={'onpromotion': bool},
    parse_dates=["date"]  # , date_parser=parser
).set_index(
    ['store_nbr', 'item_nbr', 'date']
)

items = pd.read_csv(
    "../input/items.csv",
).set_index("item_nbr")

df_2017 = df_train.loc[df_train.date>=pd.datetime(2017,1,1)]
del df_train

promo_2017_train = df_2017.set_index(
    ["store_nbr", "item_nbr", "date"])[["onpromotion"]].unstack(
        level=-1).fillna(False)
promo_2017_train.columns = promo_2017_train.columns.get_level_values(1)
promo_2017_test = df_test[["onpromotion"]].unstack(level=-1).fillna(False)
promo_2017_test.columns = promo_2017_test.columns.get_level_values(1)
promo_2017_test = promo_2017_test.reindex(promo_2017_train.index).fillna(False)
promo_2017 = pd.concat([promo_2017_train, promo_2017_test], axis=1)
del promo_2017_test, promo_2017_train

df_2017 = df_2017.set_index(
    ["store_nbr", "item_nbr", "date"])[["unit_sales"]].unstack(
        level=-1).fillna(0)
df_2017.columns = df_2017.columns.get_level_values(1)

items = items.reindex(df_2017.index.get_level_values(1))

def get_timespan(df, dt, minus, periods, freq='D'):
    return df[pd.date_range(dt - timedelta(days=minus), periods=periods, freq=freq)]

def prepare_dataset(t2017, is_train=True):
    X = pd.DataFrame({
        "day_1_2017": get_timespan(df_2017, t2017, 1, 1).values.ravel(),
        "mean_3_2017": get_timespan(df_2017, t2017, 3, 3).mean(axis=1).values,
        "mean_7_2017": get_timespan(df_2017, t2017, 7, 7).mean(axis=1).values,
        "mean_14_2017": get_timespan(df_2017, t2017, 14, 14).mean(axis=1).values,
        "mean_30_2017": get_timespan(df_2017, t2017, 30, 30).mean(axis=1).values,
        "mean_60_2017": get_timespan(df_2017, t2017, 60, 60).mean(axis=1).values,
        "mean_140_2017": get_timespan(df_2017, t2017, 140, 140).mean(axis=1).values,
        "promo_14_2017": get_timespan(promo_2017, t2017, 14, 14).sum(axis=1).values,
        "promo_60_2017": get_timespan(promo_2017, t2017, 60, 60).sum(axis=1).values,
        "promo_140_2017": get_timespan(promo_2017, t2017, 140, 140).sum(axis=1).values
    })
    for i in range(7):
        X['mean_4_dow{}_2017'.format(i)] = get_timespan(df_2017, t2017, 28-i, 4, freq='7D').mean(axis=1).values
        X['mean_20_dow{}_2017'.format(i)] = get_timespan(df_2017, t2017, 140-i, 20, freq='7D').mean(axis=1).values
    for i in range(16):
        X["promo_{}".format(i)] = promo_2017[
            t2017 + timedelta(days=i)].values.astype(np.uint8)
    if is_train:
        y = df_2017[
            pd.date_range(t2017, periods=16)
        ].values
        return X, y
    return X

print("Preparing dataset...")
t2017 = date(2017, 5, 31)
X_l, y_l = [], []
for i in range(6):
    delta = timedelta(days=7 * i)
    X_tmp, y_tmp = prepare_dataset(
        t2017 + delta
    )
    X_l.append(X_tmp)
    y_l.append(y_tmp)
X_train = pd.concat(X_l, axis=0)
y_train = np.concatenate(y_l, axis=0)
del X_l, y_l
X_val, y_val = prepare_dataset(date(2017, 7, 26))
X_test = prepare_dataset(date(2017, 8, 16), is_train=False)

stores_items = pd.DataFrame(index=df_2017.index)
test_ids = df_test[['id']]

items = items.reindex( stores_items.index.get_level_values(1) )

X_train = X_train.values
X_test = X_test.values
X_val = X_val.values
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))
X_val = X_val.reshape((X_val.shape[0], 1, X_val.shape[1]))

model = Sequential()
model.add(LSTM(32, input_shape=(X_train.shape[1],X_train.shape[2])))
model.add(Dropout(.1))
model.add(Dense(32))
model.add(Dropout(.2))
model.add(Dense(1))
model.compile(loss = 'mse', optimizer='adam', metrics=['mse'])

N_EPOCHS = 5

val_pred = []
test_pred = []
# wtpath = 'weights.hdf5'  # To save best epoch. But need Keras bug to be fixed first.
sample_weights=np.array( pd.concat([items["perishable"]] * 6) * 0.25 + 1 )
for i in range(16):
    print("=" * 50)
    print("Step %d" % (i+1))
    print("=" * 50)
    y = y_train[:, i]
    xv = X_val
    yv = y_val[:, i]
    model.fit(X_train, y, batch_size = 512, epochs = N_EPOCHS, verbose=2,
               sample_weight=sample_weights, validation_data=(xv,yv) ) 
    val_pred.append(model.predict(X_val))
    test_pred.append(model.predict(X_test))
    
n_public = 5 # Number of days in public test set
weights=pd.concat([items["perishable"]]) * 0.25 + 1
print("Unweighted validation mse: ", mean_squared_error(
    y_val, np.array(val_pred).squeeze(axis=2).transpose()) )
print("Full validation mse:       ", mean_squared_error(
    y_val, np.array(val_pred).squeeze(axis=2).transpose(), sample_weight=weights) )
print("'Public' validation mse:   ", mean_squared_error(
    y_val[:,:n_public], np.array(val_pred).squeeze(axis=2).transpose()[:,:n_public], 
    sample_weight=weights) )
print("'Private' validation mse:  ", mean_squared_error(
    y_val[:,n_public:], np.array(val_pred).squeeze(axis=2).transpose()[:,n_public:], 
    sample_weight=weights) )
    
y_test = np.array(test_pred).squeeze(axis=2).transpose()
df_preds = pd.DataFrame(
    y_test, index=stores_items.index,
    columns=pd.date_range("2017-08-16", periods=16)
).stack().to_frame("unit_sales")
df_preds.index.set_names(["store_nbr", "item_nbr", "date"], inplace=True)

submission = test_ids.join(df_preds, how="left").fillna(0)
submission["unit_sales"] = np.clip(np.expm1(submission["unit_sales"]), 0, 1000)
submission.to_csv('lstm.csv', float_format='%.4f', index=None)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
# Preparing dataset...
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# ==================================================
# Step 1
# ==================================================
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 1005090 samples, validate on 167515 samples
# Epoch 1/5
#  - 6s - loss: 0.3947 - mse: 0.3721 - val_loss: 0.3062 - val_mse: 0.3062
# Epoch 2/5
#  - 5s - loss: 0.3534 - mse: 0.3345 - val_loss: 0.3019 - val_mse: 0.3019
# Epoch 3/5
#  - 5s - loss: 0.3442 - mse: 0.3261 - val_loss: 0.3036 - val_mse: 0.3036
# Epoch 4/5
#  - 5s - loss: 0.3404 - mse: 0.3227 - val_loss: 0.3029 - val_mse: 0.3029
# Epoch 5/5
#  - 5s - loss: 0.3387 - mse: 0.3211 - val_loss: 0.2962 - val_mse: 0.2962
# ==================================================
# Step 2
# ==================================================
# Train on 1005090 samples, validate on 167515 samples
# Epoch 1/5
#  - 5s - loss: 0.3660 - mse: 0.3452 - val_loss: 0.3269 - val_mse: 0.3269
# Epoch 2/5
#  - 5s - loss: 0.3620 - mse: 0.3416 - val_loss: 0.3285 - val_mse: 0.3285
# Epoch 3/5
#  - 5s - loss: 0.3609 - mse: 0.3406 - val_loss: 0.3269 - val_mse: 0.3269
# Epoch 4/5
#  - 5s - loss: 0.3604 - mse: 0.3401 - val_loss: 0.3280 - val_mse: 0.3280
# Epoch 5/5
#  - 5s - loss: 0.3598 - mse: 0.3396 - val_loss: 0.3306 - val_mse: 0.3306
# ==================================================
# Step 3
# ==================================================
# Train on 1005090 samples, validate on 167515 samples
# Epoch 1/5
#  - 5s - loss: 0.3706 - mse: 0.3507 - val_loss: 0.3450 - val_mse: 0.3450
# Epoch 2/5
#  - 5s - loss: 0.3647 - mse: 0.3455 - val_loss: 0.3389 - val_mse: 0.3389
# Epoch 3/5
#  - 5s - loss: 0.3632 - mse: 0.3441 - val_loss: 0.3396 - val_mse: 0.3396
# Epoch 4/5
#  - 5s - loss: 0.3625 - mse: 0.3435 - val_loss: 0.3456 - val_mse: 0.3456
# Epoch 5/5
#  - 5s - loss: 0.3623 - mse: 0.3434 - val_loss: 0.3472 - val_mse: 0.3472
# ==================================================
# Step 4
# ==================================================
# Train on 1005090 samples, validate on 167515 samples
# Epoch 1/5
#  - 5s - loss: 0.3985 - mse: 0.3766 - val_loss: 0.3577 - val_mse: 0.3577
# Epoch 2/5
#  - 5s - loss: 0.3913 - mse: 0.3700 - val_loss: 0.3568 - val_mse: 0.3568
# Epoch 3/5
#  - 5s - loss: 0.3899 - mse: 0.3687 - val_loss: 0.3619 - val_mse: 0.3619
# Epoch 4/5
#  - 5s - loss: 0.3888 - mse: 0.3678 - val_loss: 0.3571 - val_mse: 0.3571
# Epoch 5/5
#  - 5s - loss: 0.3886 - mse: 0.3676 - val_loss: 0.3545 - val_mse: 0.3545
# ==================================================
# Step 5
# ==================================================
# Train on 1005090 samples, validate on 167515 samples
# Epoch 1/5
#  - 5s - loss: 0.4092 - mse: 0.3870 - val_loss: 0.3610 - val_mse: 0.3610
# Epoch 2/5
#  - 5s - loss: 0.4020 - mse: 0.3804 - val_loss: 0.3574 - val_mse: 0.3574
# Epoch 3/5
#  - 5s - loss: 0.4008 - mse: 0.3793 - val_loss: 0.3584 - val_mse: 0.3584
# Epoch 4/5
#  - 5s - loss: 0.4000 - mse: 0.3785 - val_loss: 0.3585 - val_mse: 0.3585
# Epoch 5/5
#  - 5s - loss: 0.3995 - mse: 0.3781 - val_loss: 0.3582 - val_mse: 0.3582
# ==================================================
# Step 6
# ==================================================
# Train on 1005090 samples, validate on 167515 samples
# Epoch 1/5
#  - 5s - loss: 0.3994 - mse: 0.3766 - val_loss: 0.3716 - val_mse: 0.3716
# Epoch 2/5
#  - 5s - loss: 0.3924 - mse: 0.3701 - val_loss: 0.3581 - val_mse: 0.3581
# Epoch 3/5
#  - 5s - loss: 0.3911 - mse: 0.3689 - val_loss: 0.3655 - val_mse: 0.3655
# Epoch 4/5
#  - 5s - loss: 0.3904 - mse: 0.3682 - val_loss: 0.3606 - val_mse: 0.3606
# Epoch 5/5
#  - 5s - loss: 0.3898 - mse: 0.3677 - val_loss: 0.3599 - val_mse: 0.3599
# ==================================================
# Step 7
# ==================================================
# Train on 1005090 samples, validate on 167515 samples
# Epoch 1/5
#  - 5s - loss: 0.3867 - mse: 0.3654 - val_loss: 0.4208 - val_mse: 0.4208
# Epoch 2/5
#  - 5s - loss: 0.3810 - mse: 0.3602 - val_loss: 0.4231 - val_mse: 0.4231
# Epoch 3/5
#  - 5s - loss: 0.3803 - mse: 0.3596 - val_loss: 0.4619 - val_mse: 0.4619
# Epoch 4/5
#  - 5s - loss: 0.3793 - mse: 0.3588 - val_loss: 0.4366 - val_mse: 0.4366
# Epoch 5/5
#  - 5s - loss: 0.3792 - mse: 0.3586 - val_loss: 0.4580 - val_mse: 0.4580
# ==================================================
# Step 8
# ==================================================
# Train on 1005090 samples, validate on 167515 samples
# Epoch 1/5
#  - 5s - loss: 0.3742 - mse: 0.3551 - val_loss: 0.3891 - val_mse: 0.3891
# Epoch 2/5
#  - 5s - loss: 0.3674 - mse: 0.3490 - val_loss: 0.4090 - val_mse: 0.4090
# Epoch 3/5
#  - 5s - loss: 0.3661 - mse: 0.3479 - val_loss: 0.3897 - val_mse: 0.3897
# Epoch 4/5
#  - 5s - loss: 0.3651 - mse: 0.3470 - val_loss: 0.3937 - val_mse: 0.3937
# Epoch 5/5
#  - 5s - loss: 0.3648 - mse: 0.3467 - val_loss: 0.4130 - val_mse: 0.4130
# ==================================================
# Step 9
# ==================================================
# Train on 1005090 samples, validate on 167515 samples
# Epoch 1/5
#  - 5s - loss: 0.3813 - mse: 0.3602 - val_loss: 0.3852 - val_mse: 0.3852
# Epoch 2/5
#  - 5s - loss: 0.3751 - mse: 0.3544 - val_loss: 0.3776 - val_mse: 0.3776
# Epoch 3/5
#  - 5s - loss: 0.3741 - mse: 0.3534 - val_loss: 0.3752 - val_mse: 0.3752
# Epoch 4/5
#  - 5s - loss: 0.3734 - mse: 0.3528 - val_loss: 0.3809 - val_mse: 0.3809
# Epoch 5/5
#  - 5s - loss: 0.3727 - mse: 0.3522 - val_loss: 0.3899 - val_mse: 0.3899
# ==================================================
# Step 10
# ==================================================
# Train on 1005090 samples, validate on 167515 samples
# Epoch 1/5
#  - 5s - loss: 0.3876 - mse: 0.3672 - val_loss: 0.3760 - val_mse: 0.3760
# Epoch 2/5
#  - 5s - loss: 0.3805 - mse: 0.3608 - val_loss: 0.3748 - val_mse: 0.3748
# Epoch 3/5
#  - 5s - loss: 0.3785 - mse: 0.3590 - val_loss: 0.3722 - val_mse: 0.3722
# Epoch 4/5
#  - 5s - loss: 0.3781 - mse: 0.3587 - val_loss: 0.3733 - val_mse: 0.3733
# Epoch 5/5
#  - 5s - loss: 0.3779 - mse: 0.3585 - val_loss: 0.3694 - val_mse: 0.3694
# ==================================================
# Step 11
# ==================================================
# Train on 1005090 samples, validate on 167515 samples
# Epoch 1/5
#  - 5s - loss: 0.4211 - mse: 0.3985 - val_loss: 0.3802 - val_mse: 0.3802
# Epoch 2/5
#  - 5s - loss: 0.4120 - mse: 0.3901 - val_loss: 0.3775 - val_mse: 0.3775
# Epoch 3/5
#  - 5s - loss: 0.4106 - mse: 0.3889 - val_loss: 0.3760 - val_mse: 0.3760
# Epoch 4/5
#  - 5s - loss: 0.4095 - mse: 0.3879 - val_loss: 0.3766 - val_mse: 0.3766
# Epoch 5/5
#  - 5s - loss: 0.4088 - mse: 0.3872 - val_loss: 0.3791 - val_mse: 0.3791
# ==================================================
# Step 12
# ==================================================
# Train on 1005090 samples, validate on 167515 samples
# Epoch 1/5
#  - 5s - loss: 0.4316 - mse: 0.4088 - val_loss: 0.3908 - val_mse: 0.3908
# Epoch 2/5
#  - 5s - loss: 0.4236 - mse: 0.4013 - val_loss: 0.3895 - val_mse: 0.3895
# Epoch 3/5
#  - 5s - loss: 0.4214 - mse: 0.3993 - val_loss: 0.3875 - val_mse: 0.3875
# Epoch 4/5
#  - 5s - loss: 0.4206 - mse: 0.3986 - val_loss: 0.3878 - val_mse: 0.3878
# Epoch 5/5
#  - 5s - loss: 0.4204 - mse: 0.3984 - val_loss: 0.3865 - val_mse: 0.3865
# ==================================================
# Step 13
# ==================================================
# Train on 1005090 samples, validate on 167515 samples
# Epoch 1/5
#  - 5s - loss: 0.4143 - mse: 0.3911 - val_loss: 0.3814 - val_mse: 0.3814
# Epoch 2/5
#  - 5s - loss: 0.4063 - mse: 0.3836 - val_loss: 0.3775 - val_mse: 0.3775
# Epoch 3/5
#  - 5s - loss: 0.4051 - mse: 0.3825 - val_loss: 0.3784 - val_mse: 0.3784
# Epoch 4/5
#  - 5s - loss: 0.4042 - mse: 0.3816 - val_loss: 0.3768 - val_mse: 0.3768
# Epoch 5/5
#  - 5s - loss: 0.4039 - mse: 0.3813 - val_loss: 0.3770 - val_mse: 0.3770
# ==================================================
# Step 14
# ==================================================
# Train on 1005090 samples, validate on 167515 samples
# Epoch 1/5
#  - 5s - loss: 0.3993 - mse: 0.3776 - val_loss: 0.3648 - val_mse: 0.3648
# Epoch 2/5
#  - 5s - loss: 0.3937 - mse: 0.3724 - val_loss: 0.3646 - val_mse: 0.3646
# Epoch 3/5
#  - 5s - loss: 0.3926 - mse: 0.3715 - val_loss: 0.3661 - val_mse: 0.3661
# Epoch 4/5
#  - 5s - loss: 0.3920 - mse: 0.3709 - val_loss: 0.3643 - val_mse: 0.3643
# Epoch 5/5
#  - 5s - loss: 0.3918 - mse: 0.3708 - val_loss: 0.3635 - val_mse: 0.3635
# ==================================================
# Step 15
# ==================================================
# Train on 1005090 samples, validate on 167515 samples
# Epoch 1/5
#  - 5s - loss: 0.3886 - mse: 0.3689 - val_loss: 0.3535 - val_mse: 0.3535
# Epoch 2/5
#  - 5s - loss: 0.3813 - mse: 0.3623 - val_loss: 0.3521 - val_mse: 0.3521
# Epoch 3/5
#  - 5s - loss: 0.3801 - mse: 0.3613 - val_loss: 0.3516 - val_mse: 0.3516
# Epoch 4/5
#  - 5s - loss: 0.3790 - mse: 0.3603 - val_loss: 0.3502 - val_mse: 0.3502
# Epoch 5/5
#  - 5s - loss: 0.3786 - mse: 0.3599 - val_loss: 0.3528 - val_mse: 0.3528
# ==================================================
# Step 16
# ==================================================
# Train on 1005090 samples, validate on 167515 samples
# Epoch 1/5
#  - 5s - loss: 0.3968 - mse: 0.3750 - val_loss: 0.3745 - val_mse: 0.3745
# Epoch 2/5
#  - 5s - loss: 0.3907 - mse: 0.3692 - val_loss: 0.3742 - val_mse: 0.3742
# Epoch 3/5
#  - 5s - loss: 0.3894 - mse: 0.3680 - val_loss: 0.3785 - val_mse: 0.3785
# Epoch 4/5
#  - 5s - loss: 0.3888 - mse: 0.3675 - val_loss: 0.3739 - val_mse: 0.3739
# Epoch 5/5
#  - 5s - loss: 0.3886 - mse: 0.3674 - val_loss: 0.3731 - val_mse: 0.3731
# Unweighted validation mse:  0.3693021786818639
# Full validation mse:        0.3688164781967027
# 'Public' validation mse:    0.3375418705708297
# 'Private' validation mse:   0.383032208935736

# %%
tf.test.is_gpu_available
# Out:
# <function tensorflow.python.framework.test_util.is_gpu_available(cuda_only=False, min_cuda_compute_capability=None)>

# %%
import tensorflow as tf
